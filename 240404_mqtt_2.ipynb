# %% [markdown]
# <a href="https://colab.research.google.com/github/duckwearingsocks/24-1-EWHA-class-Iot/blob/main/240404_mqtt_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install paho-mqtt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 kB 807.7 kB/s eta 0:00:00
# ...

# %%
import json
import requests
n=0

def doit(topic, payload):
  global n
  print(topic, payload)
  j=json.loads(payload)
  #print(j['co2'])
  url='https://api.thingspeak.com/update?api_key=VB3TITFCCDIYPOL4'
  url +='&field1='+j['co2']
  url +='&field2='+j['bme680'].split(',')[0]
  if n>15:
    r=requests.get(url)
    print(url, r.text)
    n=0
  n+=1

# %%
import paho.mqtt.client as mqtt

def on_connect(client, userdata, flags, reason_code, properties):
    print(f"Connected with result code {reason_code}")
    client.subscribe("connectware/indoor/data/1502")

def on_message(client, userdata, msg):
    doit(msg.topic, msg.payload.decode('utf8'))

client = mqtt.Client(mqtt.CallbackAPIVersion.VERSION2)
client.on_connect = on_connect
client.on_message = on_message

client.connect("damoa.io", 1883, 60)
client.loop_forever()
# Out:
# Connected with result code Success
# connectware/indoor/data/1502 {"dust":"50,64","co2":"588","bme680":"23.84,19.11,1835748,101059,22.17","time":"2024-04-06 22:53:35", "serial":195124, "ip":"203.255.190.49"}
# connectware/indoor/data/1502 {"dust":"50,63","co2":"588","bme680":"23.84,19.12,1842105,101059,22.17","time":"2024-04-06 22:53:36", "serial":195125, "ip":"203.255.190.49"}
# connectware/indoor/data/1502 {"dust":"50,63","co2":"587","bme680":"23.84,19.11,1837016,101060,22.17","time":"2024-04-06 22:53:37", "serial":195126, "ip":"203.255.190.49"}
# connectware/indoor/data/1502 {"dust":"49,62","co2":"587","bme680":"23.84,19.12,1847222,101059,22.17","time":"2024-04-06 22:53:38", "serial":195127, "ip":"203.255.190.49"}
# https://api.thingspeak.com/update?api_key=VB3TITFCCDIYPOL4&field1=587&field2=23.84 18
# connectware/indoor/data/1502 {"dust":"49,62","co2":"587","bme680":"23.84,19.12,1831956,101058,22.25","time":"2024-04-06 22:53:39", "serial":195128, "ip":"203.255.190.49"}
# ...
